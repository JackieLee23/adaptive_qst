# %% [markdown]
# ## Description
# Quantum state tomography on single qubit mixed states, and compared to state tomography with uniformly sampled pauli measurements

# %%
# %load_ext autoreload
# %autoreload 2
#import adaptive_qst.max_info as max_info
from qiskit.quantum_info import random_density_matrix, random_statevector, DensityMatrix
from adaptive_qst.plotting import PlotOneQubit
from adaptive_qst.max_info import Posterior, HiddenState
import matplotlib.pyplot as plt
from numpy import pi
from qiskit.quantum_info import state_fidelity

import numpy as np
from numpy import sqrt
from numpy.linalg import cholesky

# %% [markdown]
# ## Comparison with pauli basis measurements
#
# Takeaways:
# - It is sometimes better?

# %%
posterior = Posterior(1000)
fig, ax = plt.subplots()

posterior.update([0, 0], 0)
posterior.update([0, 0], 1)

posterior.update([pi/2, 0], 0)
posterior.update([pi/2, 0], 1)

posterior.update([pi/2, pi/2], 0)
posterior.update([pi/2, pi/2], 1)

posterior.resample()

PlotOneQubit.plot_posterior(posterior, 'xy', ax)

# %%
n_measurements = 1_000
pure_state = random_statevector(2)
hidden_state = HiddenState(DensityMatrix(pure_state).data)
hidden_state.hidden_state
# Out:
# array([[0.44441158+0.j        , 0.30303688+0.39380017j],
#        [0.30303688-0.39380017j, 0.55558842+0.j        ]])

# %%
infidelity_arr_mub = []
pauli_configs = [[pi/2, 0], [pi/2, pi/2], [0, 0]]

tots = np.zeros(3)
counts = np.zeros(3)
probs = 0.5 * np.ones(3)

for i in range(n_measurements):
    basis = i % 3
    result = hidden_state.measure_along_axis(pauli_configs[basis])
    
    tots[basis] += (result == 0)
    counts[basis] += 1
    
    probs[basis] = tots[basis] / counts[basis]
        
    comps = 2 * probs - 1
    
    if np.sum(comps ** 2) > 1:
        comps /= np.sum(comps ** 2)
        
    best_guess = 0.5 * np.array([[1 + comps[2], comps[0] - comps[1] * 1j],
                           [comps[0] + comps[1] * 1j, 1 - comps[2]]])
    
    infidelity_arr_mub.append(1 - state_fidelity(hidden_state.hidden_state, best_guess))

# %%
n_particles = 100
infidelity_arr_bayes = []
posterior = Posterior(n_particles)

for i in range(n_measurements):
    if i % 500 == 0:
        print(f"Step {i}")
        
    config = posterior.get_best_config()
    res = hidden_state.measure_along_axis(config)
    posterior.update(config, res)
    
    infidelity_arr_bayes.append(1 - state_fidelity(posterior.get_best_guess(), hidden_state.hidden_state))
# Out:
# Step 0
# Step 500

# %%
fig, ax = plt.subplots()

ax.plot(np.arange(n_measurements), infidelity_arr_mub, label = "Equal Pauli Basis")
ax.plot(np.arange(n_measurements), infidelity_arr_bayes, label = "Max Info Strategy")

ax.set_yscale('log')
plt.legend()

# %% [markdown]
# ## Average over 10 pure states, 5000 steps each
#
# - Do 30, 100, 300, and 1000 particles, as well as pauli mub

# %%
def run_pauli_mub(hidden_state, n_measurements):
    infidelity_arr_mub = []
    
    pauli_configs = [[pi/2, 0], [pi/2, pi/2], [0, 0]]
    tots = np.zeros(3)
    counts = np.zeros(3)
    probs = 0.5 * np.ones(3)

    for i in range(n_measurements):
        basis = i % 3
        result = hidden_state.measure_along_axis(pauli_configs[basis])

        tots[basis] += (result == 0)
        counts[basis] += 1

        probs[basis] = tots[basis] / counts[basis]

        comps = 2 * probs - 1

        if np.sum(comps ** 2) > 1:
            comps /= np.sum(comps ** 2)

        best_guess = 0.5 * np.array([[1 + comps[2], comps[0] - comps[1] * 1j],
                               [comps[0] + comps[1] * 1j, 1 - comps[2]]])

        infidelity_arr_mub.append(1 - state_fidelity(hidden_state.hidden_state, best_guess))
        
    return infidelity_arr_mub

# %%
pauli_configs = [[pi/2, 0], [pi/2, pi/2], [0, 0]]

def run_bayes(hidden_state, n_measurements, n_particles, adaptive = True):
    infidelity_arr_bayes = []
    posterior = Posterior(n_particles)

    for i in range(n_measurements):
#         if i % 500 == 0:
#             print(f"Step {i}")

        if not adaptive:
            config = pauli_configs[i % 3]
        else:
            config = posterior.get_best_config()
            
        res = hidden_state.measure_along_axis(config)
        posterior.update(config, res)

        infidelity_arr_bayes.append(1 - state_fidelity(posterior.get_best_guess(), hidden_state.hidden_state))
        
    return infidelity_arr_bayes

# %%
n_tests = 10
n_measurements = 1000

bayes_particles = [30, 100, 300]
infidelities = np.zeros((n_tests, len(bayes_particles) + 1, n_measurements))

import time
start = time.time()

for i in range(n_tests):
    print(f"Running test {i}")
    hidden_state = HiddenState(DensityMatrix(random_statevector(2)).data)
    
    
    for j, n_particles in enumerate(bayes_particles):
        print(f" - Running subtest {j}")
    
        infidelities[i, j] = run_bayes(hidden_state, n_measurements, n_particles)
        
    infidelities[i, len(bayes_particles)] = run_pauli_mub(hidden_state, n_measurements)
    
print(time.time() - start)
# Out:
# Running test 0
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 1
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 2
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 3
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 4
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 5
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 6
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 7
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 8
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 9
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 10
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 11
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 12
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 13
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 14
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 15
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 16
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 17
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 18
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 19
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 20
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 21
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 22
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 23
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 24
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 25
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 26
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 27
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 28
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 29
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 30
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 31
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 32
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 33
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 34
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 35
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 36
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 37
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 38
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 39
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 40
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 41
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 42
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 43
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 44
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 45
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 46
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 47
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 48
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# Running test 49
#  - Running subtest 0
#  - Running subtest 1
#  - Running subtest 2
# 1914.1535198688507

# %%
avgs = np.mean(infidelities, axis = 0)

fig, ax = plt.subplots()

for i, n_particles in enumerate(bayes_particles):
    ax.plot(np.arange(n_measurements), avgs[i], label = f"Max Info Strategy with {n_particles}")
    
ax.plot(np.arange(n_measurements), avgs[len(bayes_particles)], label = "Equal Pauli Basis")

ax.set_yscale('log')
ax.set_xscale('log')
plt.legend()
